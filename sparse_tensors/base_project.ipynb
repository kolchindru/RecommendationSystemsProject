# %%
import numpy as np
import pandas as pd
import os
import torch
from tqdm import tqdm_notebook

from google_drive_downloader import GoogleDriveDownloader as gdd

gdd.download_file_from_google_drive(file_id='1GNllmHs0cH8FQVu68AwrttMzere4KJhG',
                                    dest_path='./ratings.dat',
                                    unzip=True)

gdd.download_file_from_google_drive(file_id='1V91TkGCwGFfeL08jpTbzsXBMndD_zWy0',
                                    dest_path='./movies.dat',
                                    unzip=True)
# Out:
# Downloading 1V91TkGCwGFfeL08jpTbzsXBMndD_zWy0 into ./movies.dat... Done.
# Unzipping...
# /usr/local/lib/python3.6/dist-packages/google_drive_downloader/google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1V91TkGCwGFfeL08jpTbzsXBMndD_zWy0" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))

# %%
rating_data = pd.io.parsers.read_csv('ratings.dat', 
    names=['user_id', 'movie_id', 'rating', 'time'],
    engine='python', delimiter='::')

# %%
movies_data = pd.io.parsers.read_csv('movies.dat', 
    names=['movie_id', 'name', 'genre'],
    engine='python', delimiter='::')

movies_data
# Out:
#       movie_id  ...                         genre
# 0            1  ...   Animation|Children's|Comedy
# 1            2  ...  Adventure|Children's|Fantasy
# 2            3  ...                Comedy|Romance
# 3            4  ...                  Comedy|Drama
# 4            5  ...                        Comedy
# ...        ...  ...                           ...
# 3878      3948  ...                        Comedy
# 3879      3949  ...                         Drama
# 3880      3950  ...                         Drama
# 3881      3951  ...                         Drama
# 3882      3952  ...                Drama|Thriller
#
# [3883 rows x 3 columns]

# %% [markdown]
# # Data Preparation

# %%
# construct tensor I here
import datetime

rating_data['date'] = pd.to_datetime(rating_data['time'], unit='s', origin='unix')
rating_data['year'] = rating_data['date'].apply(lambda x: x.year)
rating_data['month'] = rating_data['date'].apply(lambda x: x.month)

# %%
def data_truncate(key):
    user_item_key = rating_data[['user_id', key, 'movie_id']]
    user_item_key['binary'] = np.ones(user_item_key.shape[0], dtype=np.int8)
    user_item_key = user_item_key.sort_values(by=['user_id', 'movie_id'])

    return user_item_key

# %%
def fill_extra_movies(data_user, column): 
    extra_movies = []
    users = data_user.user_id.unique()

    for user in tqdm_notebook(users):
        current_user_frame = data_user[data_user['user_id'] == user]
        movies_user = current_user_frame['movie_id'].unique()

        add_movies = np.array(list(set(all_movies) - set(movies_user)))
        qty_movies = add_movies.shape[0]

        user_rate = np.tile([user, 1], qty_movies).reshape(qty_movies, 2)
        binary_col = np.zeros(qty_movies, dtype=np.int8)[:, None]

        res_frame = np.hstack((user_rate, add_movies[:, None], binary_col))
        extra_movies.append(res_frame)

    extra_frame = pd.DataFrame(np.vstack(extra_movies), columns=['user_id', column, 'movie_id', 'binary'])
    data_new = pd.concat((data_user, extra_frame))

    return data_new

# %%
def create_pivot(data_user, column):
    pivot = pd.pivot_table(data_user, values='binary', index=['user_id', 'movie_id'],
                        columns=[column])
    
    return pivot

# %% [markdown]
# ## User $\times$ Item $\times$ Month

# %%
user_item_month = data_truncate('month')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
all_movies = np.sort(user_item_month.movie_id.unique()) #Calculate only once
data_uim = fill_extra_movies(user_item_month, 'month')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=6040.0), HTML(value='')))

# %%
uim_pivot = create_pivot(data_uim, 'month')

# %%
uim_pivot = uim_pivot.fillna(0)

# %%
num_of_users = rating_data.user_id.nunique() #Calculate only once
num_of_movies = rating_data.movie_id.nunique() #Calculate only once
num_of_months = rating_data.month.nunique()

user_movie_month_array = uim_pivot.values.reshape(num_of_users, num_of_movies, num_of_months)
sparse_user_movie_month = torch.tensor(user_movie_month_array).to_sparse()

# %% [markdown]
# ## User $\times$ Item $\times$ Rate

# %%
user_item_rate = data_truncate('rating')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_uir = fill_extra_movies(user_item_rate, 'rating')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=6040.0), HTML(value='')))

# %%
# %%time 

uir_pivot = create_pivot(data_uir, 'rating')
# Out:
# CPU times: user 21.7 s, sys: 3.32 s, total: 25 s
# Wall time: 25.1 s

# %%
uir_pivot = uir_pivot.fillna(0)

# %%
num_of_rates = rating_data.rating.nunique()

user_movie_rate_array = uir_pivot.values.reshape(num_of_users, num_of_movies, num_of_rates)
sparse_user_movie_rate = torch.tensor(user_movie_rate_array).to_sparse()

# %% [markdown]
# # Part II. Decompose (more decompositions?)

# %% [markdown]
# ### 1.[ Tucker decomposition](http://tensorly.org/stable/user_guide/tensor_decomposition.html)

# %%
# !pip install tensorly

# %%
user_movie_rate_array = torch.load('./sparse_user_movie_rate.pt')
user_movie_rate_array = np.array(user_movie_rate_array.to_dense())

# %%
user_movie_rate_array.shape
# Out:
# (6040, 3706, 5)

# %%
# %%time

from tensorly.decomposition import tucker

# decompose both tensors

core, (U, V, W) = tucker(user_movie_rate_array, rank=(20, 20, 5))
# Out:
# CPU times: user 1min 33s, sys: 3.56 s, total: 1min 37s
# Wall time: 51.6 s

# %%
core.shape, U.shape, V.shape, W.shape
# Out:
# ((20, 20, 5), (6040, 20), (3706, 20), (5, 5))

# %%
user0 = user_movie_rate_array[0]
user0.shape
# Out:
# (3706, 5)

# %%
R_user0 = V @ V.T @ user0 @ W @ W.T

# %%
merge_frames = rating_data.merge(movies_data, left_on='movie_id', right_on='movie_id')

# %%
merge_frames.head()
# Out:
#    user_id  movie_id  ...                                    name  genre
# 0        1      1193  ...  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1        2      1193  ...  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2       12      1193  ...  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3       15      1193  ...  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4       17      1193  ...  One Flew Over the Cuckoo's Nest (1975)  Drama
#
# [5 rows x 9 columns]

# %%
merge_frames[merge_frames['user_id'] == 1].sort_values(by='rating', ascending=False).head(20)
# Out:
#        user_id  ...                                 genre
# 0            1  ...                                 Drama
# 50759        1  ...          Animation|Children's|Musical
# 41626        1  ...           Animation|Children's|Comedy
# 19503        1  ...                                 Drama
# 43703        1  ...                                 Drama
# 25853        1  ...                             Drama|War
# 37339        1  ...          Animation|Children's|Musical
# 15859        1  ...                               Musical
# 28501        1  ...  Animation|Children's|Musical|Romance
# 49748        1  ...             Children's|Comedy|Musical
# 12759        1  ...          Animation|Children's|Musical
# 23270        1  ...                         Comedy|Sci-Fi
# 37204        1  ...                                 Drama
# 52255        1  ...                      Action|Drama|War
# 8926         1  ...                          Comedy|Drama
# 8222         1  ...                Action|Adventure|Drama
# 4201         1  ...           Animation|Children's|Comedy
# 40375        1  ...                                 Drama
# 36814        1  ...          Animation|Children's|Musical
# 36324        1  ...                  Animation|Children's
#
# [20 rows x 9 columns]

# %%
probs = R_user0[:, -1]
range_array = {x: y for x, y in enumerate(probs)}
movies_user0 = merge_frames[merge_frames['user_id'] == 1].movie_id.unique()
range_array = {x: y for x, y in range_array.items() if x not in movies_user0}

# %%
dict(sorted(range_array.items(), key=lambda item: item[1], reverse=True))
# Out:
# {309: 0.34401964398406654,
#  513: 0.3324525978971312,
#  0: 0.26977323180040447,
#  858: 0.26955931589891424,
#  1025: 0.2639847592069071,
#  346: 0.255524995252296,
#  579: 0.23311197359644711,
#  581: 0.20967695548752735,
#  2557: 0.20373633057838655,
#  144: 0.19455355558415913,
#  1178: 0.18975633746619944,
#  892: 0.18477012027544262,
#  1563: 0.1845001029507634,
#  2898: 0.1841601405029983,
#  354: 0.18387015914431595,
#  574: 0.18010631427190163,
#  576: 0.177971739057177,
#  963: 0.17763934749165972,
#  1107: 0.17718731062621165,
#  1848: 0.1765068289472686,
#  1108: 0.1743238322666704,
#  2599: 0.16816395921428898,
#  2203: 0.16120633374057836,
#  1781: 0.1576702008633432,
#  970: 0.15610434208328094,
#  1117: 0.15564983173463345,
#  2931: 0.14979124370878752,
#  1104: 0.14615968455079761,
#  1900: 0.14390564789261526,
#  1135: 0.14333150872503095,
#  1154: 0.14262281063917928,
#  580: 0.14144764540320753,
#  1215: 0.1395144434908062,
#  2131: 0.1388776151362067,
#  106: 0.1383803112103742,
#  957: 0.13087155798734387,
#  1190: 0.13023599070940894,
#  33: 0.12678577448005543,
#  1003: 0.12484739753385324,
#  853: 0.12463260231628484,
#  1210: 0.12424952859405242,
#  2592: 0.12327297104178173,
#  1150: 0.12255170438971635,
#  851: 0.12158903590390455,
#  859: 0.11948988582903987,
#  1143: 0.11842731867407685,
#  2710: 0.11823677594298491,
#  1838: 0.11638634897175096,
#  1186: 0.11618760300313516,
#  1618: 0.11553834615453154,
#  1899: 0.11450705939807265,
#  2162: 0.11383661330970067,
#  3238: 0.11320243590749506,
#  1767: 0.11239113506991968,
#  1956: 0.11015633880937167,
#  1574: 0.10797253663848004,
#  1897: 0.10760871321073881,
#  1158: 0.10742687078902387,
#  2078: 0.10612918924203223,
#  967: 0.1052751233239524,
#  1727: 0.10406707722092244,
#  1059: 0.09867417730572627,
#  1906: 0.09830440485747186,
#  2307: 0.09700666488112546,
#  1915: 0.096463715522735,
#  1980: 0.0947338787443159,
#  964: 0.09465354826791704,
#  838: 0.09335932786332467,
#  1167: 0.09036417894589141,
#  582: 0.08933707195535065,
#  1788: 0.08758079704380811,
#  1212: 0.08688925667803903,
#  1113: 0.08557777633076391,
#  3189: 0.08466959611533575,
#  1199: 0.0835371738054521,
#  1904: 0.08335631960892874,
#  1155: 0.08313071697186498,
#  3429: 0.08195620370454225,
#  2820: 0.08141937359284712,
#  494: 0.08086551757172399,
#  1774: 0.08034695488677683,
#  1260: 0.0797114777395871,
#  1179: 0.07927180092948832,
#  1180: 0.07916922573991682,
#  1782: 0.07902716097693951,
#  1453: 0.07868410216635975,
#  3134: 0.0783222183231037,
#  1170: 0.07742137299970976,
#  2889: 0.07733899336656348,
#  908: 0.07690180930355003,
#  253: 0.07604121324195579,
#  1018: 0.07529569125802801,
#  1201: 0.074915966898699,
#  1202: 0.07431920540574079,
#  2368: 0.07381026726538477,
#  2205: 0.07294559335444868,
#  16: 0.07251973405146284,
#  802: 0.07160256873370896,
#  3341: 0.07059156214047921,
#  1288: 0.07006747982099361,
#  1825: 0.06952755156641902,
#  1195: 0.06947805564008039,
#  1140: 0.0683510800669933,
#  2136: 0.06826711692715315,
#  60: 0.06795405791774009,
#  2556: 0.06774992195448973,
#  525: 0.06736541363237666,
#  3165: 0.06700467644954923,
#  1787: 0.06666005255615662,
#  1173: 0.06663058597539379,
#  2483: 0.06640136906115539,
#  1777: 0.06612219162435985,
#  1960: 0.0660178031170013,
#  3510: 0.06545780239740817,
#  893: 0.06526403031733878,
#  2201: 0.06510958890456026,
#  1743: 0.06497219122076872,
#  2932: 0.0648131599581558,
#  2879: 0.06423155129388117,
#  1958: 0.06404767384647515,
#  1184: 0.06380352839334118,
#  3177: 0.0636538169141136,
#  2775: 0.062094140628004606,
#  1959: 0.06169568920981343,
#  2102: 0.06153864191434545,
#  1281: 0.06152214328037552,
#  1294: 0.061341736987759334,
#  960: 0.061336660583883124,
#  483: 0.06120583226709074,
#  35: 0.06004588888477185,
#  2511: 0.059940014139282835,
#  1886: 0.05988698602948506,
#  1066: 0.05981428971109793,
#  1865: 0.05975186859113081,
#  515: 0.059672324316876836,
#  3131: 0.05947490138123503,
#  2586: 0.058856933917657936,
#  958: 0.05795767888129326,
#  2534: 0.057645389264360206,
#  3508: 0.0567413142251719,
#  49: 0.05647943243055119,
#  3031: 0.05597147769759729,
#  2143: 0.05588912853446026,
#  2012: 0.0554699846678186,
#  1478: 0.05412321204768704,
#  2884: 0.054039085564773215,
#  443: 0.05368376293599466,
#  843: 0.05298781413125552,
#  947: 0.05181016016314065,
#  2943: 0.05151243030356468,
#  1129: 0.05143268225673945,
#  639: 0.05132532775734885,
#  849: 0.05049297910830201,
#  3236: 0.050093895340410394,
#  539: 0.049775627775329304,
#  968: 0.04936646735767748,
#  3426: 0.04926562611591684,
#  1174: 0.048961853198969986,
#  1177: 0.04864450734346428,
#  1133: 0.04860570777978751,
#  537: 0.04786364656806221,
#  3669: 0.047797472021910134,
#  1297: 0.04695248766190124,
#  1944: 0.046910611576402535,
#  2819: 0.04689843098603687,
#  1902: 0.046520391357367824,
#  1541: 0.04615549927960465,
#  517: 0.046021281640218584,
#  1171: 0.045860922541114874,
#  327: 0.045816983038043824,
#  847: 0.04577124857610955,
#  3216: 0.04487874851861273,
#  740: 0.04483687285192875,
#  2426: 0.04455421976153902,
#  287: 0.04438104250213766,
#  2976: 0.04433453499975672,
#  1114: 0.04405342402119143,
#  737: 0.04395774006703615,
#  3028: 0.04392816971180211,
#  2166: 0.043678876536914255,
#  2110: 0.043669221138366146,
#  3503: 0.04324313729598853,
#  1166: 0.043156813269915426,
#  1504: 0.04306799879754629,
#  1537: 0.042690477442086316,
#  1551: 0.042648093571004936,
#  2501: 0.042247339750900455,
#  3167: 0.04222233571115323,
#  1555: 0.04221637556690499,
#  971: 0.04186746243770809,
#  1935: 0.04169595100948039,
#  841: 0.04161546208488741,
#  601: 0.041551038283483645,
#  3166: 0.04153868621507179,
#  3550: 0.04149016295606036,
#  1277: 0.04125880501122137,
#  3277: 0.04109103724620026,
#  3256: 0.04068127926259254,
#  948: 0.04063509817359724,
#  3651: 0.040540517774681734,
#  2872: 0.04031969464419856,
#  3433: 0.04020676459216273,
#  1439: 0.039674207351347655,
#  2882: 0.03938163350581019,
#  1909: 0.03923244662094243,
#  2438: 0.03908468963235497,
#  1027: 0.03905183366707849,
#  573: 0.03902773650143081,
#  2230: 0.03889493188947451,
#  954: 0.038129898688266536,
#  1236: 0.037860481925665976,
#  708: 0.037558846845287076,
#  2523: 0.03687181064388295,
#  258: 0.036723278453405866,
#  1918: 0.036623581349223985,
#  583: 0.036297304510423636,
#  689: 0.03606295663897774,
#  466: 0.036004902612460435,
#  3274: 0.03579423526486,
#  1775: 0.03556326773821667,
#  855: 0.035493854879429174,
#  1780: 0.03531082586658836,
#  1118: 0.03500728957312025,
#  1398: 0.03497454037161961,
#  756: 0.03494568884105219,
#  1191: 0.03493516201843855,
#  3219: 0.0348422028295425,
#  3318: 0.034833752956616545,
#  1096: 0.03481007645629042,
#  255: 0.03477189499840846,
#  323: 0.03472103693656769,
#  966: 0.03465381375511953,
#  3246: 0.03459253921879046,
#  952: 0.03441559363816429,
#  3266: 0.03386906086820937,
#  862: 0.03373963214751254,
#  1007: 0.03345066176894592,
#  1502: 0.033437455098263104,
#  1136: 0.03326896194819173,
#  1047: 0.03313821861047918,
#  1130: 0.0330377760638972,
#  1957: 0.032836293819772676,
#  632: 0.03278995972991119,
#  2482: 0.032328380520066285,
#  3047: 0.03231845329296647,
#  1309: 0.03198079442405538,
#  3130: 0.03151333344157795,
#  3599: 0.031195470818949984,
#  991: 0.031005484423719126,
#  510: 0.030923929743164068,
#  47: 0.03078449579844348,
#  1258: 0.030541086791444023,
#  837: 0.030360909342768354,
#  3481: 0.030259215925240907,
#  1908: 0.03021412264122331,
#  2013: 0.03003947392992928,
#  2821: 0.029914985376021337,
#  1747: 0.029908795288273848,
#  1161: 0.029697261601006223,
#  3155: 0.029684891867262246,
#  1134: 0.029502411407201955,
#  1776: 0.029440354333978336,
#  254: 0.02908849134813569,
#  3293: 0.02898801195673815,
#  1771: 0.028883900641327946,
#  46: 0.028776865568636165,
#  56: 0.02876515873072157,
#  155: 0.02874089736879939,
#  108: 0.028639964383051122,
#  965: 0.028564749028741024,
#  2958: 0.028267462451677196,
#  10: 0.028070206159241964,
#  426: 0.028048164054730023,
#  593: 0.028025049512614895,
#  3315: 0.028012927285517013,
#  291: 0.027881333017526384,
#  1878: 0.02784755965873362,
#  3701: 0.02762005269237319,
#  1148: 0.02761723670089408,
#  1449: 0.027371986289827305,
#  1032: 0.027310309301408865,
#  2518: 0.027269116014665286,
#  1024: 0.027226457511027657,
#  2238: 0.02718408219754737,
#  2961: 0.02717529498507504,
#  1460: 0.02663870905896524,
#  1693: 0.026554629710352183,
#  2505: 0.026439245590978728,
#  2993: 0.026234242170752955,
#  1921: 0.02593864419735992,
#  1867: 0.0258018321786547,
#  2480: 0.025584286906332066,
#  1165: 0.025469942261402423,
#  2120: 0.02545644918476487,
#  2650: 0.0254027014184726,
#  1273: 0.02534829611971776,
#  1115: 0.025290720963104148,
#  246: 0.025252991919957366,
#  2736: 0.02522232434442082,
#  2590: 0.02515854006589912,
#  1769: 0.025014229804406037,
#  2865: 0.024993690665612873,
#  3279: 0.024869706878492867,
#  2220: 0.024737788540384793,
#  101: 0.024639405740825862,
#  3622: 0.024635000607992463,
#  319: 0.02461585737822631,
#  307: 0.02452243284751926,
#  1194: 0.024394636380024478,
#  2046: 0.024318076624114046,
#  786: 0.024185089154237404,
#  2200: 0.024112237870011703,
#  3022: 0.024095721228262253,
#  1817: 0.02385470760855925,
#  2375: 0.02373370734482568,
#  2838: 0.023656644885902446,
#  104: 0.023653212481939252,
#  3375: 0.023515389152645998,
#  1934: 0.02347269526987385,
#  2159: 0.023426168600801073,
#  1259: 0.023393802023493095,
#  923: 0.02331456789668227,
#  2495: 0.02330965392124145,
#  3218: 0.023247313021634852,
#  2957: 0.02315537710414566,
#  2856: 0.022975732486716038,
#  1852: 0.022971572129186893,
#  2420: 0.022898859923184973,
#  1012: 0.022708946747532495,
#  653: 0.022599737212010536,
#  486: 0.022543587765048455,
#  3384: 0.022503901075109023,
#  1055: 0.02247660386005659,
#  1969: 0.022464905374575742,
#  1183: 0.02237169809757657,
#  23: 0.02229685940948898,
#  1314: 0.02226149959809514,
#  1292: 0.022244851125077035,
#  3311: 0.02219452774562986,
#  461: 0.022170542362110992,
#  1729: 0.022154329298741136,
#  679: 0.022080668462147728,
#  71: 0.021905051816597052,
#  3566: 0.02188213979029984,
#  242: 0.02181855198981256,
#  538: 0.021577714037068613,
#  3303: 0.02136859283782923,
#  1016: 0.021274885168329063,
#  950: 0.02121567522116661,
#  2308: 0.02113654425289879,
#  1204: 0.02103380664459704,
#  1820: 0.021029891297291835,
#  1094: 0.020952190924434566,
#  1628: 0.020839295993651225,
#  879: 0.020778158638833543,
#  3475: 0.020756552765776808,
#  2504: 0.020742296705506678,
#  1543: 0.020616715059063116,
#  2121: 0.020604848663941643,
#  2939: 0.020597773246856688,
#  759: 0.02042742511228897,
#  1770: 0.020410668343311424,
#  2794: 0.02032801798893545,
#  1993: 0.02031448449067426,
#  2846: 0.020310104010022333,
#  3542: 0.02003884165100324,
#  174: 0.019999037192140287,
#  2455: 0.01999437833041273,
#  3617: 0.01995623672086933,
#  352: 0.01994364262773408,
#  1737: 0.019941746086380552,
#  335: 0.019922815382355376,
#  839: 0.019892337013405988,
#  506: 0.019841788561209935,
#  2664: 0.01983621887857617,
#  2633: 0.019824158289886644,
#  854: 0.019775435570511916,
#  1457: 0.01943868341648596,
#  136: 0.019394399790253994,
#  1925: 0.019303880056955776,
#  992: 0.01926512598185912,
#  1835: 0.0191592680293846,
#  2105: 0.019143725298594087,
#  414: 0.01899123909985875,
#  2733: 0.01895177515415151,
#  2701: 0.018888901542007164,
#  1008: 0.018855107139014157,
#  1933: 0.01877244819312755,
#  2490: 0.01875989106283389,
#  3049: 0.018675449682293597,
#  3244: 0.018652762719314497,
#  649: 0.01862133502108661,
#  850: 0.018564331479995522,
#  1486: 0.018523341988384553,
#  2978: 0.018294989029518424,
#  857: 0.018172750160728845,
#  2469: 0.018119511184930114,
#  1832: 0.018070278403224987,
#  3206: 0.018031875428417207,
#  1305: 0.017973817490020482,
#  43: 0.017918877356132276,
#  1740: 0.017904112284793362,
#  3250: 0.017888447263002715,
#  358: 0.017878608479125823,
#  578: 0.017871348478240838,
#  1890: 0.01783661071436467,
#  1084: 0.0176804074302482,
#  3328: 0.01760961348171466,
#  3029: 0.01759798647820509,
#  224: 0.017587407147881044,
#  2128: 0.0174114387212324,
#  572: 0.01738808873912685,
#  1963: 0.01718871468868388,
#  1306: 0.01716420997076553,
#  2540: 0.017069125391812774,
#  1912: 0.017030747201385876,
#  959: 0.017025890374027228,
#  3178: 0.016936567835887997,
#  873: 0.016919836548461714,
#  962: 0.016896717832664592,
#  1182: 0.016880930848923732,
#  1653: 0.016868495970029318,
#  1942: 0.016840619306437214,
#  232: 0.01682908442096341,
#  3120: 0.01678899822265678,
#  3275: 0.016744688929338357,
#  1054: 0.016645814981955356,
#  852: 0.01657950489955626,
#  1162: 0.016524542277563208,
#  3377: 0.01651655969197638,
#  955: 0.016441663342185293,
#  1826: 0.0164405968418328,
#  308: 0.016314084045532577,
#  2621: 0.01630207036252023,
#  347: 0.01615166734395469,
#  2788: 0.01613128643932379,
#  1526: 0.01612912393444425,
#  977: 0.01610917642417686,
#  610: 0.016085311004158158,
#  844: 0.01606619711052981,
#  1275: 0.016051382268243063,
#  1582: 0.015999754348673123,
#  3197: 0.015893477801069592,
#  1031: 0.015843360023400546,
#  152: 0.015821114185780413,
#  520: 0.01580542756367095,
#  3314: 0.01577662694528507,
#  1751: 0.015767033036738938,
#  2969: 0.01572060145507579,
#  3502: 0.01569219673924058,
#  2952: 0.015665489585179698,
#  1303: 0.015651973938619827,
#  2814: 0.015619076977094406,
#  2639: 0.015613176172674614,
#  856: 0.01553054900509055,
#  2972: 0.015526708682899652,
#  949: 0.015487944812550789,
#  305: 0.015358630098277135,
#  785: 0.015307641511226468,
#  3070: 0.015292560330067031,
#  1903: 0.015243155227380354,
#  141: 0.015196821021603994,
#  3265: 0.015157883621498076,
#  67: 0.015128978325646053,
#  704: 0.015095742403044633,
#  1715: 0.014993870589413339,
#  1272: 0.014844506405513717,
#  428: 0.01479956149644194,
#  735: 0.014662321237050338,
#  1206: 0.014488222138917588,
#  25: 0.014385279853729139,
#  1857: 0.014282806846123321,
#  1841: 0.014198871017566627,
#  2839: 0.014148077287058476,
#  3511: 0.014088864887466145,
#  58: 0.013993240473733962,
#  3636: 0.013992540628822154,
#  871: 0.013967564249145885,
#  2514: 0.013963139525085185,
#  1924: 0.01392840647290406,
#  1517: 0.01391936056731843,
#  2446: 0.013901277653593759,
#  2857: 0.013852527168269154,
#  2404: 0.01385234963725962,
#  1516: 0.013762144041924699,
#  2940: 0.013722300399134383,
#  2235: 0.013719440387599167,
#  2285: 0.013666409754880949,
#  3509: 0.013604479938589407,
#  2738: 0.013575481646127978,
#  2583: 0.013568662571282156,
#  2823: 0.013557511312547767,
#  3220: 0.013482687139918343,
#  2346: 0.013416999327669087,
#  3126: 0.01340990203948732,
#  3233: 0.013397542894949677,
#  3122: 0.01334870313214983,
#  259: 0.013327267241288921,
#  501: 0.013299411578733622,
#  2164: 0.013246655379676758,
#  1567: 0.013234372065896113,
#  2384: 0.01315844008512006,
#  1205: 0.01315683856823245,
#  1089: 0.013141598636598816,
#  2683: 0.01311688863650621,
#  1459: 0.013112607295882275,
#  996: 0.013081960851007728,
#  2140: 0.01298967521065326,
#  1778: 0.01295575950648276,
#  3664: 0.012932976255056086,
#  1871: 0.012913093298988246,
#  894: 0.012886763101118458,
#  2496: 0.012809241472478463,
#  1853: 0.012799177837039677,
#  2489: 0.012727817238051442,
#  2470: 0.012661212890266999,
#  1764: 0.012565144541827805,
#  3132: 0.01249680104863048,
#  2541: 0.012492426287793358,
#  210: 0.012421836825209673,
#  1598: 0.012268045633941807,
#  842: 0.012262196794750279,
#  2897: 0.012234710064465328,
#  2634: 0.012075195884283586,
#  1896: 0.01205035376009862,
#  1779: 0.012042815971023198,
#  972: 0.012016886962111768,
#  2227: 0.01199269015799179,
#  190: 0.01193638107830815,
#  1928: 0.011922982572805588,
#  1142: 0.011874919722635564,
#  1556: 0.011864754485325089,
#  1340: 0.011854618491775678,
#  12: 0.011797737982393709,
#  2783: 0.011766574594842554,
#  2214: 0.011692045305001415,
#  1014: 0.011691704734694212,
#  2108: 0.011688783141754942,
#  882: 0.011661324051053388,
#  317: 0.01163028391546018,
#  532: 0.01160854822296984,
#  2760: 0.011578669063998265,
#  2486: 0.011559449752287699,
#  544: 0.011554902865877906,
#  2830: 0.011517782492337975,
#  1274: 0.011477219194217533,
#  2460: 0.011450236978867259,
#  1492: 0.011402074247708007,
#  1276: 0.011387085637559047,
#  298: 0.01123474804194852,
#  2007: 0.011101917089391726,
#  1185: 0.011098370275239973,
#  2099: 0.011096145170487903,
#  1021: 0.011096054772514062,
#  1765: 0.011031824167990997,
#  3555: 0.011003678096599544,
#  1981: 0.010906053088038117,
#  945: 0.010890533557498503,
#  166: 0.010843695352818889,
#  1755: 0.010796862072297176,
#  3091: 0.010795602632739149,
#  169: 0.010755462795615825,
#  1144: 0.010701890109368527,
#  17: 0.010698991634654733,
#  3035: 0.010690470838741608,
#  877: 0.010668115055848353,
#  2063: 0.01056910081867674,
#  3026: 0.010493810779034522,
#  805: 0.010421606568554606,
#  795: 0.010359887564958009,
#  3627: 0.010272910133005186,
#  2956: 0.010266258766418705,
#  3383: 0.01023476795411316,
#  1371: 0.01022992219229305,
#  15: 0.010181569525128983,
#  1954: 0.010065273032866666,
#  2929: 0.010064589459485922,
#  2415: 0.010009383694967249,
#  561: 0.009982673751230459,
#  651: 0.009980504884978435,
#  944: 0.009951399926936277,
#  993: 0.009890261532765203,
#  2161: 0.009885176662321877,
#  1613: 0.009851414411357022,
#  2851: 0.00984762716250453,
#  1364: 0.009844565080368928,
#  2082: 0.00979730415788325,
#  3353: 0.009750252076428526,
#  369: 0.00970622648944075,
#  872: 0.00961394219313761,
#  2274: 0.009529564048693552,
#  2682: 0.009511454381621048,
#  1013: 0.009498499620664042,
#  239: 0.009438168554688799,
#  2567: 0.009438106785702496,
#  753: 0.009434401975741823,
#  3059: 0.009342125225258598,
#  2118: 0.009304483369293366,
#  1521: 0.009195949100843872,
#  1734: 0.009122346343654797,
#  1910: 0.00910466445344517,
#  1614: 0.00909973040623144,
#  2353: 0.009078230947348049,
#  596: 0.009074052120357142,
#  2497: 0.009051304265444697,
#  167: 0.009044296472818548,
#  1988: 0.009023783750491067,
#  867: 0.00897115243274252,
#  2784: 0.008918936027506529,
#  2930: 0.008867029365160713,
#  3215: 0.008853490160882776,
#  1772: 0.008803136696199249,
#  2962: 0.00877709518416025,
#  3136: 0.008750831862974349,
#  3491: 0.008745453738673603,
#  3543: 0.008742208273608856,
#  1913: 0.008741954413299037,
#  91: 0.008674861531643966,
#  1766: 0.008665150393365162,
#  1048: 0.008653202736080712,
#  2206: 0.00862343961441014,
#  3074: 0.00860084382346983,
#  2383: 0.008580564436428491,
#  1970: 0.008525031572613596,
#  2142: 0.00851448221975271,
#  3586: 0.008496867670396634,
#  3582: 0.008441670169910955,
#  2243: 0.008432289943449281,
#  3455: 0.008428136962802613,
#  3261: 0.008418181034395778,
#  477: 0.008408157003311439,
#  1757: 0.008403988995908081,
#  2109: 0.00837303393276639,
#  2895: 0.008367456859780917,
#  2257: 0.008360093580633913,
#  2774: 0.008345873728694586,
#  3559: 0.008319134366508888,
#  2919: 0.008317463364927143,
#  1657: 0.00830747060941119,
#  953: 0.00830083622464285,
#  393: 0.008291434229019795,
#  1849: 0.008289498458790217,
#  2669: 0.008275824112966502,
#  2407: 0.008243188953911554,
#  318: 0.008236442219696827,
#  356: 0.008207951975887633,
#  3625: 0.008198011175827474,
#  1759: 0.008175477870814594,
#  2042: 0.008154195994252532,
#  407: 0.008128743891979082,
#  1044: 0.008126456701367855,
#  3643: 0.008120445163229885,
#  1200: 0.008119018277223678,
#  3671: 0.008113616915683824,
#  1762: 0.008096966848425704,
#  822: 0.008084458511687985,
#  182: 0.008070929453643976,
#  463: 0.008055579095920166,
#  357: 0.00803548947980738,
#  1211: 0.008027303364712121,
#  1824: 0.008008667771252245,
#  3705: 0.00800823629367344,
#  2442: 0.007895615427561816,
#  780: 0.007853856586084585,
#  691: 0.007841770114289362,
#  1570: 0.007821851215943209,
#  529: 0.007815654660150183,
#  1241: 0.007805504352302025,
#  2250: 0.007774765357280445,
#  519: 0.00776050648131964,
#  1953: 0.007744503453668925,
#  2964: 0.0077303588620807025,
#  1414: 0.007722269125241106,
#  3046: 0.007710710537108666,
#  498: 0.007638826496187573,
#  2014: 0.007629090597626015,
#  3251: 0.0075529729379528445,
#  848: 0.00754062370261935,
#  2302: 0.007526259666363167,
#  1744: 0.007512119582868387,
#  3072: 0.0075102092208360486,
#  1678: 0.00746569270717637,
#  641: 0.007460347157815362,
#  3127: 0.0074508873847214194,
#  2603: 0.007404868809595544,
#  3168: 0.007403772306773695,
#  391: 0.007398181725671594,
#  1862: 0.007385947312238293,
#  887: 0.00730714326157507,
#  3364: 0.007234861058711218,
#  3023: 0.0072166691465134075,
#  755: 0.007207857273829238,
#  2840: 0.00719247859185005,
#  2260: 0.007162304713724019,
#  330: 0.007148928449145822,
#  3615: 0.007115136365139087,
#  910: 0.007107826025444507,
#  3568: 0.007090630440730517,
#  2892: 0.007052209968357618,
#  1668: 0.0070509827031967134,
#  790: 0.006969810170698963,
#  1451: 0.006969408262529917,
#  1351: 0.006900266507258068,
#  348: 0.006889601411215986,
#  3516: 0.00686505106009425,
#  2196: 0.006850340362244569,
#  1864: 0.006846881749352393,
#  1209: 0.006798982247005472,
#  3366: 0.006797270104985719,
#  3376: 0.00679053709616349,
#  1879: 0.00678715037142067,
#  1099: 0.006709617421294364,
#  328: 0.0066759863214392355,
#  505: 0.006649036419151734,
#  3247: 0.006639117125279121,
#  3478: 0.0066362228296058656,
#  164: 0.006622744543719928,
#  3329: 0.006579365105971059,
#  2090: 0.006548973030207672,
#  1702: 0.006522188487801411,
#  3418: 0.006437467984577645,
#  3619: 0.006435813415408902,
#  3354: 0.006433907599096695,
#  3228: 0.006417720881448948,
#  2413: 0.006376765286149747,
#  883: 0.0063689177980976765,
#  902: 0.006339747027452786,
#  1676: 0.006336323832930668,
#  3098: 0.006320536776095187,
#  2960: 0.006307375472202819,
#  3581: 0.0063029495089043435,
#  2397: 0.006283118746439578,
#  3456: 0.006278935079459131,
#  2559: 0.006266034168436515,
#  7: 0.006229385235520455,
#  3040: 0.006227968950957009,
#  1911: 0.006213264147168338,
#  888: 0.006212875147646116,
#  2345: 0.006207931563647655,
#  1876: 0.0061912051659303476,
#  1176: 0.006169890936588469,
#  2517: 0.006127292321791564,
#  2542: 0.006116264678415728,
#  61: 0.006109398576436689,
#  1793: 0.006100724446079888,
#  1860: 0.0060998828833188625,
#  1773: 0.0060840678807209765,
#  1602: 0.0060673312569912785,
#  2144: 0.0060657837570151805,
#  931: 0.006049280850166965,
#  1049: 0.006046784974942558,
#  2255: 0.006029824953172635,
#  1553: 0.005975804094588384,
#  2244: 0.00596370045961227,
#  2721: 0.005946571266675434,
#  1761: 0.005899290114515061,
#  2847: 0.005878638249604733,
#  1814: 0.005849376570752281,
#  2210: 0.005819616251082141,
#  427: 0.005818916116370079,
#  2405: 0.005817083599806629,
#  817: 0.005812480469917758,
#  2654: 0.005795401373624141,
#  2306: 0.005780034521174598,
#  2073: 0.0057211479360369105,
#  1837: 0.00570273333082257,
#  74: 0.005687398710697583,
#  626: 0.0056859995211589985,
#  495: 0.005667681493411622,
#  3650: 0.0056582259998061045,
#  2508: 0.005653908349539332,
#  1661: 0.005645866645999807,
#  1916: 0.005634838552519493,
#  1490: 0.005634081748814442,
#  394: 0.005629521966321359,
#  2864: 0.005603533609650458,
#  889: 0.005556329395571422,
#  2431: 0.0055516297008168305,
#  3558: 0.005531634184750817,
#  2423: 0.005496796568163573,
#  2371: 0.005496760760547523,
#  776: 0.005496219029559706,
#  3612: 0.005472705043851235,
#  3061: 0.005471951909557294,
#  111: 0.0054695825441695425,
#  165: 0.0054688631361071785,
#  2172: 0.005457505555762069,
#  2675: 0.005433829229126282,
#  2180: 0.005419458016037198,
#  2352: 0.005410436699666959,
#  1701: 0.005391448041724132,
#  3320: 0.005375413364903903,
#  2614: 0.005355167455700525,
#  1905: 0.00532025461056243,
#  1472: 0.005314955272164501,
#  251: 0.005307161172441776,
#  3180: 0.005302931998549056,
#  2254: 0.005280290908590481,
#  2672: 0.005269273564343652,
#  2312: 0.005266381889182121,
#  304: 0.005209697523036938,
#  2615: 0.005199955287222239,
#  1605: 0.005197309079796669,
#  2263: 0.005184506783485896,
#  3467: 0.005145405669862387,
#  956: 0.005141407262597039,
#  275: 0.0051090722855893405,
#  1686: 0.005105329224222861,
#  2058: 0.0051049591690918335,
#  1745: 0.005067579131116231,
#  334: 0.0050459017587988104,
#  2566: 0.00502526841942838,
#  951: 0.0049778333745778966,
#  1561: 0.00497274972285393,
#  2653: 0.004939002553116639,
#  3378: 0.004916519467108479,
#  3358: 0.004910974397187223,
#  3533: 0.0049089750839441245,
#  2119: 0.0048863941927620134,
#  2691: 0.004878357693932169,
#  145: 0.0048766028299097874,
#  3312: 0.004876037148812287,
#  3036: 0.004872097741372181,
#  1815: 0.004868584231422829,
#  884: 0.004863788110891516,
#  3624: 0.004835665323842857,
#  3623: 0.0048276144034875845,
#  2589: 0.004823824701266625,
#  1630: 0.004814454526316739,
#  1741: 0.004789761369433298,
#  399: 0.004786270686056551,
#  1375: 0.00477366964950079,
#  2002: 0.004772521806855744,
#  2975: 0.004719738563376092,
#  3668: 0.0047186683609144325,
#  1269: 0.004696778922709495,
#  1690: 0.004690480829722218,
#  1791: 0.00467740389773331,
#  609: 0.004658188045664732,
#  986: 0.0046561067518483615,
#  1868: 0.00465594764734358,
#  3667: 0.00464348165124701,
#  1506: 0.004639311940880648,
#  762: 0.004632004366940885,
#  2622: 0.004596076777049663,
#  84: 0.0045863538675751945,
#  451: 0.004575207212039909,
#  3541: 0.00455949177947707,
#  826: 0.004542370600968558,
#  798: 0.004542175941480202,
#  40: 0.004535099127319676,
#  1355: 0.0045259017748846145,
#  1806: 0.004519083691333992,
#  3430: 0.004509307619084402,
#  2990: 0.004502266023670282,
#  1164: 0.0044900001570253876,
#  2595: 0.004467287547667926,
#  2684: 0.004457058891091044,
#  1888: 0.004456127141730906,
#  3269: 0.004452596435704874,
#  2364: 0.004414119784759352,
#  1105: 0.00441341908388229,
#  1889: 0.004395276231788881,
#  935: 0.004378807282315021,
#  1151: 0.0043722875149562095,
#  162: 0.004367033580743619,
#  833: 0.004365232399448803,
#  1798: 0.004361955494853725,
#  355: 0.004349895200581067,
#  1249: 0.00432013499955378,
#  1789: 0.004319094086705253,
#  1792: 0.004316661296640287,
#  2942: 0.004313541390771614,
#  827: 0.004299129959894577,
#  11: 0.004289881020904578,
#  288: 0.004265030405924054,
#  444: 0.0042617211186620815,
#  266: 0.004222336264319643,
#  2973: 0.004208503737247874,
#  312: 0.00419940581825519,
#  2941: 0.004191799414752404,
#  670: 0.00417990218542579,
#  3515: 0.004176151494906766,
#  1301: 0.004172902513123718,
#  3280: 0.004160245509102219,
#  1800: 0.0040658931421916735,
#  2909: 0.004065039812936822,
#  3285: 0.004054576770258525,
#  2673: 0.004046099419459268,
#  290: 0.004032846640791398,
#  2899: 0.0040227930522562455,
#  1254: 0.004021650709497745,
#  2739: 0.0040099550477115655,
#  832: 0.003997520725479881,
#  3689: 0.00396038080226203,
#  2509: 0.0039376748450395275,
#  2755: 0.0039221106697562074,
#  2135: 0.003905817579956157,
#  880: 0.0038751799046671405,
#  64: 0.003848167199574874,
#  2758: 0.003824548407072443,
#  2194: 0.0038238681402168895,
#  3356: 0.0038184546258111956,
#  130: 0.0038159321016268725,
#  2516: 0.0038099718288368235,
#  1805: 0.003809300338082022,
#  2249: 0.003805525981564099,
#  2825: 0.003792281369871166,
#  2335: 0.0037895589185165906,
#  3532: 0.0037891749373279177,
#  1901: 0.0037607019208119167,
#  80: 0.0037320719469970463,
#  1336: 0.0037171914156631544,
#  2403: 0.0036937344453655545,
#  2016: 0.0036914707998778697,
#  272: 0.003679378149992884,
#  3100: 0.0036566122526288506,
#  1552: 0.0036476395721524546,
#  779: 0.003599929076484237,
#  415: 0.003585297261084991,
#  265: 0.0035519205090969617,
#  1188: 0.003546162857774878,
#  1938: 0.003543764908235275,
#  703: 0.0035405664335479738,
#  2656: 0.0035375362614330588,
#  2363: 0.00351623564840847,
#  3321: 0.003516192006954122,
#  320: 0.0035148048659831062,
#  1223: 0.0034974588917288485,
#  2870: 0.003496753364183224,
#  1799: 0.003491788075208669,
#  3703: 0.0034845093870077234,
#  39: 0.00345772842429134,
#  1601: 0.003448759638498136,
#  1922: 0.0034270101248474413,
#  2874: 0.0034185745092671837,
#  2681: 0.0034183707761562348,
#  1866: 0.003414443138158754,
#  1932: 0.0033743378426695425,
#  1941: 0.0033579286458663773,
#  90: 0.0033491848405893267,
#  1578: 0.0033487263519390497,
#  3322: 0.0033391870673568132,
#  563: 0.0033370590646541326,
#  1403: 0.003318446546035567,
#  1920: 0.0033162607648059904,
#  1638: 0.0033013314091519088,
#  3666: 0.0032952550635049855,
#  270: 0.0032922205135412297,
#  3696: 0.003289860883114991,
#  3611: 0.0032756674471248115,
#  819: 0.003273450428428784,
#  234: 0.0032610319424158387,
#  3655: 0.0032565626026488793,
#  1391: 0.0032549185561805303,
#  3576: 0.003231306395515969,
#  86: 0.0032228940674097536,
#  2347: 0.003220609033069757,
#  2310: 0.003215733314966485,
#  3207: 0.003209429343837925,
#  2515: 0.003204623718718468,
#  151: 0.003189919279600547,
#  2763: 0.0031858282065685166,
#  2926: 0.003172791197760724,
#  2439: 0.003168976786969061,
#  3235: 0.003154152668415382,
#  3208: 0.0031478641689275918,
#  3419: 0.0031116171361977203,
#  1818: 0.0031035157228534913,
#  2258: 0.0030916847383520994,
#  738: 0.0030871469926715685,
#  30: 0.0030680874514139892,
#  1790: 0.0030613042706558275,
#  322: 0.0030597057826536535,
#  2080: 0.003046405242512687,
#  243: 0.003029734626896306,
#  2041: 0.003017124817591609,
#  1423: 0.0030051847188880573,
#  823: 0.002979297095553507,
#  2454: 0.002973921802769232,
#  1347: 0.0029373201646625126,
#  1854: 0.002934665471852726,
#  1975: 0.0029263093697351242,
#  1796: 0.0029234630097646494,
#  1208: 0.002904221949168372,
#  2122: 0.002896090410690993,
#  121: 0.0028874785450081946,
#  1557: 0.0028699121095209453,
#  315: 0.0028646650523344833,
#  470: 0.0028511953894642143,
#  2569: 0.0028450329622419415,
#  2716: 0.0028422738413133356,
#  2369: 0.0028385640423613328,
#  2705: 0.0028277909935516335,
#  149: 0.0028205149893686895,
#  1982: 0.0028166250942192796,
#  1682: 0.002811949961565555,
#  1875: 0.002811421566660177,
#  2605: 0.0027970973145293922,
#  2484: 0.0027965750451201974,
#  ...}

# %%
movies_data[movies_data['movie_id'] == 309]
# Out:
#      movie_id                                       name  genre
# 306       309  Red Firecracker, Green Firecracker (1994)  Drama

# %% [markdown]
# ### 2. [HOSVD decomposition](https://pytorch.org/docs/stable/generated/torch.svd.html) or [Lowrank HOSVD decomposition](https://pytorch.org/docs/stable/generated/torch.svd_lowrank.html)

# %%
# decompose both tensors
